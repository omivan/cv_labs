# %% [markdown]
# ### Gradient Descent
#
# In this notebook we will demonstrate how gradient descent works. We will use the same example as in the slides.

# %%
import numpy as np
from matplotlib import pyplot as plt

# Training data
x = np.array([1, 2])     # Number of drinks
y = np.array([6, 12])    # Price in euros

# %% [markdown]
# #### Definition of Neuron

# %%
class Neuron:
    def __init__(self, weight=4):
        self.weight = weight

    def __call__(self, x):
        return self.weight * x

    def __repr__(self):
        return f'Neuron weight: {self.weight:.5f}'

# %% [markdown]
# #### Definition of Model
#
# We need to also define the neural network (or model) itself. In our simple case, the model will consist of only one single neuron.
#
# Moreover, inorder to conduct the optimization, we shall define the loss function and its corresponding derivative with respect to **all** of the network parameters (the so called gradient).

# %%
class Network():
    def __init__(self):
        self.neuron = Neuron()
        self.grad = None

    def loss(self, x, y):
        self.grad = np.sum(2 * (self.neuron(x) - y) * x)
        return np.sum((self.neuron(x) - y)**2)

# %% [markdown]
# #### Training
#
# We will now apply the gradient descent algorithm to find the parameters that minimize the loss we defined earlier.

# %%
model = Network()

lr = 0.07
for _ in range(50):
    loss = model.loss(x, y)
    model.neuron.weight = model.neuron.weight - lr * model.grad
    print(model.neuron, model.grad, loss)
# Out:
# Neuron weight: 5.40000 -20 20
# Neuron weight: 5.82000 -5.9999999999999964 1.799999999999998
# Neuron weight: 5.94600 -1.7999999999999972 0.1619999999999995
# Neuron weight: 5.98380 -0.5400000000000027 0.014580000000000147
# Neuron weight: 5.99514 -0.16200000000000436 0.0013122000000000706
# Neuron weight: 5.99854 -0.048599999999998644 0.0001180979999999934
# Neuron weight: 5.99956 -0.014579999999995152 1.0628819999992933e-05
# Neuron weight: 5.99987 -0.004374000000000322 9.565938000001409e-07
# Neuron weight: 5.99996 -0.0013122000000009848 8.609344200012922e-08
# Neuron weight: 5.99999 -0.0003936600000020718 7.748409780081558e-09
# Neuron weight: 6.00000 -0.00011809800000150972 6.973568802178294e-10
# Neuron weight: 6.00000 -3.5429400000452915e-05 6.276211921960465e-11
# Neuron weight: 6.00000 -1.0628820001912231e-05 5.648590731652476e-12
# Neuron weight: 6.00000 -3.1886459961327773e-06 5.083731644326796e-13
# Neuron weight: 6.00000 -9.565937997280116e-07 4.5753584883903756e-14
# Neuron weight: 6.00000 -2.8697813903022507e-07 4.117822614062559e-15
# Neuron weight: 6.00000 -8.609344348542436e-08 3.706040505588979e-16
# Neuron weight: 6.00000 -2.5828033045627308e-08 3.335436455030081e-17
# Neuron weight: 6.00000 -7.748406360974514e-09 3.001890056739515e-18
# Neuron weight: 6.00000 -2.3245227964707738e-09 2.701703115656153e-19
# Neuron weight: 6.00000 -6.973532862275533e-10 2.4315080290618396e-20
# Neuron weight: 6.00000 -2.092015449761675e-10 2.1882643210207716e-21
# Neuron weight: 6.00000 -6.275868713601085e-11 1.9693264055178468e-22
# Neuron weight: 6.00000 -1.8829382497642655e-11 1.7727282262126577e-23
# Neuron weight: 6.00000 -5.6488147492927965e-12 1.595455403591392e-24
# Neuron weight: 6.00000 -1.6964207816272392e-12 1.4389217341683866e-25
# Neuron weight: 6.00000 -5.062616992290714e-13 1.2815045405315337e-26
# Neuron weight: 6.00000 -1.509903313490213e-13 1.139904008044362e-27
# Neuron weight: 6.00000 -4.440892098500626e-14 9.860761315262648e-29
# Neuron weight: 6.00000 -8.881784197001252e-15 3.944304526105059e-30
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0
# Neuron weight: 6.00000 0.0 0.0

# %% [markdown]
# ### Tensorflow Implementation
#
# Let's now implement the same neural network model using Tensorflow.

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input

# %%
inputs = Input(shape=(1))
outputs = Dense(1, activation="linear", use_bias=True)(inputs)
model = Model(inputs, outputs)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3312/734923800.py in <cell line: 0>()
# ----> 1 inputs = Input(shape=(1))
#       2 outputs = Dense(1, activation="linear", use_bias=True)(inputs)
#       3 model = Model(inputs, outputs)
#       4
#       5 model.summary()
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py in Input(shape, batch_size, dtype, sparse, ragged, batch_shape, name, tensor, optional)
#     208     ```
#     209     """
# --> 210     layer = InputLayer(
#     211         shape=shape,
#     212         batch_size=batch_size,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py in __init__(self, shape, batch_size, dtype, sparse, ragged, batch_shape, input_tensor, optional, name, **kwargs)
#      90
#      91             if shape is not None:
# ---> 92                 shape = backend.standardize_shape(shape)
#      93                 batch_shape = (batch_size,) + shape
#      94
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/common/variables.py in standardize_shape(shape)
#     594             raise ValueError("Undefined shapes are not supported.")
#     595         if not hasattr(shape, "__iter__"):
# --> 596             raise ValueError(f"Cannot convert '{shape}' to a shape.")
#     597         if config.backend() == "tensorflow":
#     598             if isinstance(shape, tf.TensorShape):
#
# ValueError: Cannot convert '1' to a shape.

# %% [markdown]
# #### Model Training

# %%
model.compile(optimizer ='sgd', loss = 'mean_squared_error')
model.fit(x, y, epochs=2000, batch_size=1)

# %% [markdown]
# After the traning, we can check the parameters that the network has learnt.

# %%
model.layers[1].weights[0].numpy()
